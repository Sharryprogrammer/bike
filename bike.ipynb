# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_excel(r'C:\Users\91831\Desktop\bike_buyers_clean.xlsx')

# %%
da=pd.DataFrame(dataset)
da
# Out:
#         ID Marital Status  Gender  Income  Children        Education  \
# 0    12496        Married  Female   40000         1        Bachelors
# 1    24107        Married    Male   30000         3  Partial College
# 2    14177        Married    Male   80000         5  Partial College
# 3    24381         Single    Male   70000         0        Bachelors
# 4    25597         Single    Male   30000         0        Bachelors
# ..     ...            ...     ...     ...       ...              ...
# 995  23731        Married    Male   60000         2      High School
# 996  28672         Single    Male   70000         4  Graduate Degree
# 997  11809        Married    Male   60000         2        Bachelors
# 998  19664         Single    Male  100000         3        Bachelors
# 999  12121         Single    Male   60000         3      High School
#
#          Occupation  Home Owner  Cars Commute Distance        Region  Age  \
# ...

# %%
da.corr()
# Out:
#                       ID    Income  Children  Home Owner      Cars       Age  \
# ID              1.000000 -0.077371 -0.031532   -0.139402  0.024308 -0.054262
# Income         -0.077371  1.000000  0.258558    0.017608  0.447695  0.169128
# Children       -0.031532  0.258558  1.000000    0.157649  0.273985  0.530621
# Home Owner     -0.139402  0.017608  0.157649    1.000000 -0.072044  0.114745
# Cars            0.024308  0.447695  0.273985   -0.072044  1.000000  0.190577
# Age            -0.054262  0.169128  0.530621    0.114745  0.190577  1.000000
# Purchased Bike  0.056357  0.042306 -0.121603   -0.019324 -0.201921 -0.106068
#
#                 Purchased Bike
# ID                    0.056357
# Income                0.042306
# Children             -0.121603
# Home Owner           -0.019324
# Cars                 -0.201921
# Age                  -0.106068
# Purchased Bike        1.000000

# %%
nos=(da["Purchased Bike"]==0).sum()
yess=(da["Purchased Bike"]==1).sum()
print("Purchased ",yess)
print("Not Purchased ",nos)
# Out:
# Purchased  481
# Not Purchased  519

# %%
sns.countplot(x='Gender', hue = 'Purchased Bike', data = da,
palette = 'Set1')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x='Purchased Bike', hue = 'Region', data = da,
palette = 'Set1')
# Out:
# <AxesSubplot:xlabel='Purchased Bike', ylabel='count'>

# %%
sns.countplot(x='Purchased Bike', hue = 'Occupation', data = da,
palette = 'Set1')
# Out:
# <AxesSubplot:xlabel='Purchased Bike', ylabel='count'>

# %%
sns.countplot(x='Age', hue = 'Purchased Bike', data = da,
palette = 'Set1')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Marital Status', hue = 'Purchased Bike', data = da,
palette = 'Set1')
# Out:
# <AxesSubplot:xlabel='Marital Status', ylabel='count'>

# %%
sns.countplot(x='Income', hue = 'Purchased Bike', data = da,
palette = 'Set1')
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
sns.countplot(x='Education', hue = 'Purchased Bike', data = da,
palette = 'Set1')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
sns.countplot(x='Cars', hue = 'Purchased Bike', data = da,
palette = 'Set1')
# Out:
# <AxesSubplot:xlabel='Cars', ylabel='count'>

# %%
sns.countplot(x='Children', hue = 'Purchased Bike', data = da,
palette = 'Set1')
# Out:
# <AxesSubplot:xlabel='Children', ylabel='count'>

# %%
sns.countplot(x='Home Owner', hue = 'Purchased Bike', data = da,
palette = 'Set1')
# Out:
# <AxesSubplot:xlabel='Home Owner', ylabel='count'>

# %%
sns.countplot(x='Home Owner', hue = 'Purchased Bike', data = da,
palette = 'Set1')
# Out:
# <AxesSubplot:xlabel='Home Owner', ylabel='count'>

# %%
da.head(5)
# Out:
#       ID Marital Status  Gender  Income  Children        Education  \
# 0  12496        Married  Female   40000         1        Bachelors
# 1  24107        Married    Male   30000         3  Partial College
# 2  14177        Married    Male   80000         5  Partial College
# 3  24381         Single    Male   70000         0        Bachelors
# 4  25597         Single    Male   30000         0        Bachelors
#
#        Occupation  Home Owner  Cars Commute Distance   Region  Age  \
# 0  Skilled Manual           1     0        0-1 Miles   Europe   42
# 1        Clerical           1     1        0-1 Miles   Europe   43
# 2    Professional           0     2        2-5 Miles   Europe   60
# 3    Professional           1     1       5-10 Miles  Pacific   41
# 4        Clerical           0     0        0-1 Miles   Europe   36
#
#    Purchased Bike
# 0               0
# 1               0
# 2               0
# 3               1
# 4               1

# %%
da['Education']=pd.Categorical(da['Education'])

# %%
da['Occupation']=pd.Categorical(da['Occupation'])

# %%
da['Commute Distance']=pd.Categorical(da['Commute Distance'])
da['Region']=pd.Categorical(da['Region'])
da['Gender']=pd.Categorical(da['Gender'])
da['Home Owner']=pd.Categorical(da['Home Owner'])

# %%
da['Marital Status']=pd.Categorical(da['Marital Status'])

# %%
da=pd.get_dummies(da,drop_first=True)
da
# Out:
#         ID  Income  Children  Cars  Age  Purchased Bike  \
# 0    12496   40000         1     0   42               0
# 1    24107   30000         3     1   43               0
# 2    14177   80000         5     2   60               0
# 3    24381   70000         0     1   41               1
# 4    25597   30000         0     0   36               1
# ..     ...     ...       ...   ...  ...             ...
# 995  23731   60000         2     2   54               1
# 996  28672   70000         4     0   35               1
# 997  11809   60000         2     0   38               1
# 998  19664  100000         3     3   38               0
# 999  12121   60000         3     2   53               1
#
#      Marital Status_Single  Gender_Male  Education_Graduate Degree  \
# 0                        0            0                          0
# 1                        0            1                          0
# 2                        0            1                          0
# ...

# %%
y=da["Purchased Bike"]
# X=da["Age","Region","Commute Distance","Cars","Home Owner","Occupation","Education","Children","Income","Gender","Marital Status"]
da=da.drop("ID",axis=1)#vertical
X=da.drop("Purchased Bike",axis=1)
da
# Out:
#      Income  Children  Cars  Age  Purchased Bike  Marital Status_Single  \
# 0     40000         1     0   42               0                      0
# 1     30000         3     1   43               0                      0
# 2     80000         5     2   60               0                      0
# 3     70000         0     1   41               1                      1
# 4     30000         0     0   36               1                      1
# ..      ...       ...   ...  ...             ...                    ...
# 995   60000         2     2   54               1                      0
# 996   70000         4     0   35               1                      1
# 997   60000         2     0   38               1                      0
# 998  100000         3     3   38               0                      1
# 999   60000         3     2   53               1                      1
#
#      Gender_Male  Education_Graduate Degree  Education_High School  \
# ...

# %%
# from sklearn.ensemble import RandomForestRegressor
# regressor=RandomForestRegressor(n_estimators=150,random_state=0)
# regressor.fit(X,y)

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(n_estimators=100,random_state=0)
regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
regressor.score(X_train, y_train)
# Out:
# 0.876095779744461

# %%
regressor.score(X_test, y_test)
# 1-regressor.score(X_test, y_test)
# Out:
# 0.19721802394703647
